# %% [markdown]
# # Outliers

# %%
import pandas as pd

# %%
df = pd.read_parquet("datasets/diabets_non_null.parquet")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6    148.0           72.0  ...                     0.627   50        1
# 1            1     85.0           66.0  ...                     0.351   31        0
# 2            8    183.0           64.0  ...                     0.672   32        1
# 3            1     89.0           66.0  ...                     0.167   21        0
# 4            0    137.0           40.0  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
from feature_utils import get_columns_type

# %%
numeric_cols, categoric_cols, cardinal_cols = get_columns_type(df)
# Out:
# 2023-03-12 04:01:29,387 - logging_utils - DEBUG - get_columns_type executing...
# 2023-03-12 04:01:29,392 - logging_utils - INFO -
# Numeric Columns: ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
# Categoric Columns: ['Outcome']
# Cardinal Columns: []

# %% [markdown]
# ## Check Outliers One by One

# %%
from feature_utils import check_outliers

# %%
check_outliers(df, columns=numeric_cols, plot=1, q1_value=0.02, q3_value=0.98)
# Out:
# 2023-03-12 04:01:31,941 - logging_utils - DEBUG - check_outliers executing...
# 2023-03-12 04:01:32,560 - logging_utils - INFO - Dataframe Columns Outliers State:
# 2023-03-12 04:01:32,564 - logging_utils - INFO - Pregnancies --> False
# 2023-03-12 04:01:32,568 - logging_utils - INFO - Glucose --> False
# 2023-03-12 04:01:32,570 - logging_utils - INFO - BloodPressure --> False
# 2023-03-12 04:01:32,573 - logging_utils - INFO - SkinThickness --> False
# 2023-03-12 04:01:32,575 - logging_utils - INFO - Insulin --> False
# 2023-03-12 04:01:32,577 - logging_utils - INFO - BMI --> False
# 2023-03-12 04:01:32,579 - logging_utils - INFO - DiabetesPedigreeFunction --> False
# 2023-03-12 04:01:32,582 - logging_utils - INFO - Age --> False

# %% [markdown]
# There is no outliers one by one.

# %% [markdown]
# ## Save Dataframe

# %%
df.to_parquet("datasets/diabetes_non_outliers.parquet")

# %% [markdown]
# Continue with **eda jupyter file**.
